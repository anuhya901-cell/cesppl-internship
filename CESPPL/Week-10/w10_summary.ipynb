# %% [markdown]
# # Week 10 Summary
#
# This week focused on evaluating the final EfficientNetB0 model, comparing model performance across experiments, and performing detailed error analysis.
#
# The evaluation included per-class metrics, confusion matrix generation, prediction confidence analysis, and manual inspection of misclassified validation images.

# %%
import pandas as pd

summary = pd.DataFrame({
    "Metric": [
        "Validation Accuracy",
        "Macro F1 Score",
        "Validation Samples",
        "Misclassified Images"
    ],
    "Value": [
        "95.03%",
        "93.31%",
        543,
        27
    ]
})

display(summary)
# Out:
#                  Metric   Value
# 0   Validation Accuracy  95.03%
# 1        Macro F1 Score  93.31%
# 2    Validation Samples     543
# 3  Misclassified Images      27

# %% [markdown]
# ## Key Learnings
#
# - Learned how to evaluate deep learning models beyond accuracy.
# - Generated confusion matrices and per-class metrics.
# - Used top-3 confidence scores to understand model uncertainty.
# - Performed systematic error analysis on misclassified images.
# - Identified visually similar classes as the major source of errors.
# - Learned how to document model performance in a research-oriented manner.

# %% [markdown]
# ## Future Improvements
#
# - Increase dataset size for confusing classes.
# - Apply stronger data augmentation.
# - Experiment with larger EfficientNet variants.
# - Explore attention mechanisms and Grad-CAM.
# - Deploy the trained model as a web application.
